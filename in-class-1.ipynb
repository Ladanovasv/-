# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import networkx as nx

# %%
G = nx.read_gml(r'/content/drive/MyDrive/ДЗ/Теория графов/karate.gml', label=None)

# %%
nx.draw(G)

# %%
G = nx.Graph()
G.add_nodes_from(range(10))
nx.draw(G, with_labels=True)

# %%
G.add_edge(0, 3)
nx.draw_circular(G, with_labels=True)

# %%
G.add_edges_from([(2, 3), (3, 5)])
nx.draw_circular(G, with_labels=True)

# %%
from itertools import combinations

# %%
G = nx.Graph()
G.add_nodes_from(range(10))
G.add_edges_from(combinations(range(4), 2))
nx.draw_circular(G, with_labels=True)

# %%
G = nx.cycle_graph(5)
nx.draw_kamada_kawai(G, with_labels=True)

# %%
G = nx.complete_graph(5)
nx.draw_kamada_kawai(G, with_labels=True)

# %%
G = nx.complete_bipartite_graph(5, 3)
nx.draw_shell(G, with_labels=True)

# %%
G = nx.lollipop_graph(5, 3)
nx.draw_kamada_kawai(G, with_labels=True)

# %%
G = nx.petersen_graph()
nx.draw_kamada_kawai(G, with_labels=True)

# %% [markdown]
# Задания на конструирование графа в networkx
#
# 1 Создайте Jupyter Notebook, подключив в нём библиотеку networkx.

# %%
import networkx as nx

# %% [markdown]
# 2 Создайте с нуля (только с помощью add_nodes_from и add_edges_from) граф типа
# lollipop (но без использования встроенной в networkx функции lollipop_graph) —
# клику на 10 вершинах, к которой приделана цепь на 6 вершинах. Нарисуйте этот
# граф наиболее подходящим по Вашему мнению алгоритмом, предоставляемым
# networkx — поэкспериментируйте.

# %%
G = nx.lollipop_graph(10, 6)
nx.draw_kamada_kawai(G, with_labels=True)

# %%
G = nx.Graph()
G.add_nodes_from(range(16))
G.add_edges_from(combinations(range(10), 2))

G.add_edges_from([(i, i+1) for i in range(9, 15)])
nx.draw_circular(G, with_labels=True)
